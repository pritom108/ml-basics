# %% [markdown]
# # 4️⃣ Feature Engineering — Key Techniques Overview ✨
#
# - **🔢 Numerical Features**:
#   - ⚖️ Scaling / Normalization: StandardScaler, MinMaxScaler, RobustScaler
#   - 🔄 Transformation: Log, Box-Cox, Yeo-Johnson, Polynomial features
#   - 📊 Discretization / Binning: equal-width, equal-frequency
#
# - **🗂️ Categorical Features**:
#   - 🏷️ Label Encoding
#   - 🔢 One-Hot Encoding
#   - 📈 Ordinal Encoding
#   - 🎯 Target/Mean Encoding
#   - 🔁 Frequency Encoding
#
# - **🕒 Date & Time Features**:
#   - 📅 Extract components: year, month, day, day-of-week, hour
#   - ⏳ Lag features for time series
#   - ➖ Compute differences / duration
#   - 🔄 Encode cyclical features: sin/cos transformations
#
# - **📝 Text Features**:
#   - 🗂️ Bag of Words (CountVectorizer)
#   - 🆚 TF-IDF (TfidfVectorizer)
#   - 🔤 N-grams: unigrams, bigrams, trigrams
#   - 🌐 Word embeddings: Word2Vec, GloVe, FastText
#   - ✍️ Custom text features: length, punctuation count, sentiment, keywords
#
# - **❓ Handling Missing Values**:
#   - 🧩 Imputation: mean/median/mode for numeric, constant/"Unknown" for categorical
#   - 🤖 Model-based imputation: KNN, iterative imputer
#   - 🚩 Flag missing values with indicator columns
#
# - **⚠️ Outlier Handling**:
#   - ✂️ Truncation / Clipping at percentiles
#   - 🔄 Transformation (log, sqrt)
#   - ❌ Removal of extreme values
#   - 🛡️ Robust scaling
#
# - **🛠️ Feature Creation / Extraction**:
#   - 🔗 Interaction features: multiply/divide/add/subtract columns
#   - 🧮 Polynomial features: squares, cubes, cross-products
#   - 📊 Aggregations: mean, sum, count for group features
#   - 🌀 Decomposition: PCA, SVD, ICA, TSNE
#   - 🏷️ Clustering features: cluster IDs as additional features
#
# - **🎯 Feature Selection Techniques**:
#   - 🔍 Filter methods: correlation threshold, chi-squared, ANOVA
#   - ⚙️ Wrapper methods: Recursive Feature Elimination (RFE), Sequential Feature Selection
#   - 🌳 Embedded methods: Tree-based feature importance, L1 regularization (Lasso)
#
# - **💡 Best Practices**:
#   - 👀 Visualize feature distributions to detect skew or outliers
#   - ⚖️ Scale features when required by algorithms (SVM, KNN, logistic regression)
#   - 🏷️ Encode categorical variables appropriately
#   - ❌ Avoid data leakage: compute features using training set only
#   - 🔗 Combine multiple techniques for better performance
#   - 🗂️ Keep transformations reproducible with pipelines
